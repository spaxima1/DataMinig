# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Stars.csv")

# %%
data
# Out:
#      Temperature              L          R    A_M  Color Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12    Red              M     0
# 1           3042       0.000500     0.1542  16.60    Red              M     0
# 2           2600       0.000300     0.1020  18.70    Red              M     0
# 3           2800       0.000200     0.1600  16.65    Red              M     0
# 4           1939       0.000138     0.1030  20.06    Red              M     0
# ..           ...            ...        ...    ...    ...            ...   ...
# 235        38940  374830.000000  1356.0000  -9.93   Blue              O     5
# 236        30839  834042.000000  1194.0000 -10.63   Blue              O     5
# 237         8829  537493.000000  1423.0000 -10.73  White              A     5
# 238         9235  404940.000000  1112.0000 -11.23  White              A     5
# 239        37882  294903.000000  1783.0000  -7.80   Blue              O     5
#
# [240 rows x 7 columns]

# %%
color=data['Color']
lbl = LabelEncoder()
a=lbl.fit_transform(color)
data['Color']=a

# %%
data
# Out:
#      Temperature              L          R    A_M  Color Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12      8              M     0
# 1           3042       0.000500     0.1542  16.60      8              M     0
# 2           2600       0.000300     0.1020  18.70      8              M     0
# 3           2800       0.000200     0.1600  16.65      8              M     0
# 4           1939       0.000138     0.1030  20.06      8              M     0
# ..           ...            ...        ...    ...    ...            ...   ...
# 235        38940  374830.000000  1356.0000  -9.93      0              O     5
# 236        30839  834042.000000  1194.0000 -10.63      0              O     5
# 237         8829  537493.000000  1423.0000 -10.73      9              A     5
# 238         9235  404940.000000  1112.0000 -11.23      9              A     5
# 239        37882  294903.000000  1783.0000  -7.80      0              O     5
#
# [240 rows x 7 columns]

# %%
Spectral_Class=data['Spectral_Class']
lbl = LabelEncoder()
a=lbl.fit_transform(Spectral_Class)
data['Spectral_Class']=a

# %%
data
# Out:
#      Temperature              L          R    A_M  Color  Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12      8               5     0
# 1           3042       0.000500     0.1542  16.60      8               5     0
# 2           2600       0.000300     0.1020  18.70      8               5     0
# 3           2800       0.000200     0.1600  16.65      8               5     0
# 4           1939       0.000138     0.1030  20.06      8               5     0
# ..           ...            ...        ...    ...    ...             ...   ...
# 235        38940  374830.000000  1356.0000  -9.93      0               6     5
# 236        30839  834042.000000  1194.0000 -10.63      0               6     5
# 237         8829  537493.000000  1423.0000 -10.73      9               0     5
# 238         9235  404940.000000  1112.0000 -11.23      9               0     5
# 239        37882  294903.000000  1783.0000  -7.80      0               6     5
#
# [240 rows x 7 columns]

# %%
selectrandom=np.random.randint(0,240,size=10)
selectrandom
# Out:
# array([126, 187, 123,  28,  13,  79, 178, 205,  15,  84])

# %%
newTemp=data['Temperature'].copy()
newTemp[list(selectrandom)]=np.nan
data['newTemp']=newTemp

# %%
data
# Out:
#      Temperature              L          R    A_M  Color  Spectral_Class  \
# 0           3068       0.002400     0.1700  16.12      8               5
# 1           3042       0.000500     0.1542  16.60      8               5
# 2           2600       0.000300     0.1020  18.70      8               5
# 3           2800       0.000200     0.1600  16.65      8               5
# 4           1939       0.000138     0.1030  20.06      8               5
# ..           ...            ...        ...    ...    ...             ...
# 235        38940  374830.000000  1356.0000  -9.93      0               6
# 236        30839  834042.000000  1194.0000 -10.63      0               6
# 237         8829  537493.000000  1423.0000 -10.73      9               0
# 238         9235  404940.000000  1112.0000 -11.23      9               0
# 239        37882  294903.000000  1783.0000  -7.80      0               6
#
#      Type  newTemp
# 0       0   3068.0
# 1       0   3042.0
# 2       0   2600.0
# ...

# %%
selectrandom1=np.random.randint(0,240,size=10)
selectrandom1
# Out:
# array([164,  60,  96,  36,  11, 116, 160, 200,  47, 104])

# %%
newL=data['L'].copy()
newL[list(selectrandom1)]=np.nan
data['newL']=newL

# %%
data
# Out:
#      Temperature              L          R    A_M  Color  Spectral_Class  \
# 0           3068       0.002400     0.1700  16.12      8               5
# 1           3042       0.000500     0.1542  16.60      8               5
# 2           2600       0.000300     0.1020  18.70      8               5
# 3           2800       0.000200     0.1600  16.65      8               5
# 4           1939       0.000138     0.1030  20.06      8               5
# ..           ...            ...        ...    ...    ...             ...
# 235        38940  374830.000000  1356.0000  -9.93      0               6
# 236        30839  834042.000000  1194.0000 -10.63      0               6
# 237         8829  537493.000000  1423.0000 -10.73      9               0
# 238         9235  404940.000000  1112.0000 -11.23      9               0
# 239        37882  294903.000000  1783.0000  -7.80      0               6
#
#      Type  newTemp           newL
# 0       0   3068.0       0.002400
# ...

# %%
# data['newTemp'].plot(kind = "hist",  bins = 15)
data['newTemp'].plot(kind = "kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data['newTempmedian']=data['newTemp'].replace(np.nan,data['newTemp'].median())

# %%
data
# Out:
#      Temperature              L          R    A_M  Color  Spectral_Class  \
# 0           3068       0.002400     0.1700  16.12      8               5
# 1           3042       0.000500     0.1542  16.60      8               5
# 2           2600       0.000300     0.1020  18.70      8               5
# 3           2800       0.000200     0.1600  16.65      8               5
# 4           1939       0.000138     0.1030  20.06      8               5
# ..           ...            ...        ...    ...    ...             ...
# 235        38940  374830.000000  1356.0000  -9.93      0               6
# 236        30839  834042.000000  1194.0000 -10.63      0               6
# 237         8829  537493.000000  1423.0000 -10.73      9               0
# 238         9235  404940.000000  1112.0000 -11.23      9               0
# 239        37882  294903.000000  1783.0000  -7.80      0               6
#
#      Type  newTemp           newL  newTempmedian
# ...

# %%
data[['Temperature','newTemp','newTempmedian']].loc[data['newTemp']!=data['newTempmedian']]
# Out:
#      Temperature  newTemp  newTempmedian
# 13          3628      NaN         5868.0
# 15          3340      NaN         5868.0
# 28         11790      NaN         5868.0
# 79          3158      NaN         5868.0
# 84         14100      NaN         5868.0
# 123         3146      NaN         5868.0
# 126         2935      NaN         5868.0
# 178        12100      NaN         5868.0
# 187         3484      NaN         5868.0
# 205        19920      NaN         5868.0

# %%
data['newL'].plot(kind = "kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data['newLmedian']=data['newL'].copy().replace(np.nan,data['newL'].median())

# %%
data.loc[data['newLmedian']!=data['newL']]
# Out:
#      Temperature            L          R    A_M  Color  Spectral_Class  Type  \
# 11          3129       0.0122     0.3761  11.79      8               5     1
# 36          6757       1.4300     1.1200   2.41     15               2     3
# 47          3574  200000.0000    89.0000  -5.24      8               5     4
# 60          3341       0.0056     0.0570  16.23      8               5     0
# 96          5112       0.6300     0.8760   4.68      6               4     3
# 104        11096  112000.0000    12.0000  -5.91      0               6     4
# 116         4015  282000.0000  1534.0000 -11.39      8               4     5
# 160        25390  223000.0000    57.0000  -5.92      0               6     4
# 164         8927  239000.0000    35.0000  -7.34      0               6     4
# 200        16790       0.0014     0.0121  12.87      0               1     2
#
#      newTemp  newL  newTempmedian  newLmedian
# 11    3129.0   NaN         3129.0      0.0305
# ...

# %% [markdown]
# <h1 style="color:blue;" dir=rtl>سوال دوم</h1>

# %%
data['newLType']=data['newL'].copy()

# %%
data['Type'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int64)

# %%
import matplotlib.pyplot as plt

# %%
for i in data['Type'].unique():
    plt.subplot()
    data['newLType'].loc[data['Type']==i].plot(kind = "kde")
    plt.show()

# %%
listtemp=[]
for i in data['Type'].unique():
    index=data['newLType'].loc[data['Type']==i].copy()
    index=index.replace(np.nan,index.median())
    listtemp+=list(index.values)

data['newLType']=listtemp

# %%
data[['L','newL','newLmedian','newLType']].loc[data['newL']!=data['L']]
# Out:
#                L  newL  newLmedian       newLType
# 11        0.0122   NaN      0.0305       0.000670
# 36        1.4300   NaN      0.0305       0.000461
# 47   200000.0000   NaN      0.0305       0.003670
# 60        0.0056   NaN      0.0305       0.000190
# 96        0.6300   NaN      0.0305       0.000780
# 104  112000.0000   NaN      0.0305       0.000670
# 116  282000.0000   NaN      0.0305       0.001590
# 160  223000.0000   NaN      0.0305  200000.000000
# 164  239000.0000   NaN      0.0305  280000.000000
# 200       0.0014   NaN      0.0305  270000.000000

# %%
data['newTempmedianType']=data['newTemp'].copy()
for i in data['Type'].unique():
    plt.subplot()
    data['newTempmedianType'].loc[data['Type']==i].plot(kind = "hist")
    plt.show()

# %%
listtemp=[]
for i in data['Type'].unique():
    index=data['newTempmedianType'].loc[data['Type']==i].copy()
    index=index.replace(np.nan,index.median())
    listtemp+=list(index.values)

data['newTempmedianType']=listtemp

# %%
data[['Temperature','newTemp','newTempmedian','newTempmedianType']].loc[data['newTemp']!=data['Temperature']]
# Out:
#      Temperature  newTemp  newTempmedian  newTempmedianType
# 13          3628      NaN         5868.0             2835.0
# 15          3340      NaN         5868.0             3295.0
# 28         11790      NaN         5868.0             2856.0
# 79          3158      NaN         5868.0             3463.0
# 84         14100      NaN         5868.0            16500.0
# 123         3146      NaN         5868.0             9700.0
# 126         2935      NaN         5868.0             6757.0
# 178        12100      NaN         5868.0            24345.0
# 187         3484      NaN         5868.0            26373.0
# 205        19920      NaN         5868.0             3450.0

# %%
from matplotlib.pyplot import figure

figure(figsize=(20, 20), dpi=80)

# %%
fig, axs = plt.subplots(2, 2, sharey=True, tight_layout=True,figsize=(15,15))
data['Temperature'].plot(kind = "hist",ax=axs[0,0])
data['newTemp'].plot(kind = "hist",ax=axs[0,1])
data['newTempmedian'].plot(kind = "hist",ax=axs[1,0])
data['newTempmedianType'].plot(kind = "hist",ax=axs[1,1])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.corr()
# Out:
#                    Temperature         L         R       A_M     Color  \
# Temperature           1.000000  0.393404  0.064216 -0.420261 -0.680107
# L                     0.393404  1.000000  0.526516 -0.692619 -0.379181
# R                     0.064216  0.526516  1.000000 -0.608728 -0.011242
# A_M                  -0.420261 -0.692619 -0.608728  1.000000  0.328318
# Color                -0.680107 -0.379181 -0.011242  0.328318  1.000000
# Spectral_Class       -0.207852  0.275280  0.097124 -0.085840  0.018774
# Type                  0.411129  0.676845  0.660975 -0.955276 -0.304993
# newTemp               1.000000  0.392028  0.058499 -0.416871 -0.681181
# newL                  0.397365  1.000000  0.526448 -0.690522 -0.383636
# newTempmedian         0.991302  0.398414  0.064582 -0.421114 -0.670467
# newLmedian            0.394333  0.984761  0.517067 -0.665413 -0.367215
# newLType              0.224729  0.374584  0.244845 -0.156480 -0.263450
# ...
